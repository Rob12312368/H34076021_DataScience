# %%
def topthree(csvdata,field):
    ratings={}
    for data in csvdata:
        if data[field['year']]=='2016': #pick movies in 2016
            ratings[data[field['title']]]=data[field['rating']]
    top3={}
    top3={title:rating for title,rating in sorted(ratings.items(), key=lambda item:item[1], reverse=True)} #sort the dict
    #print(top3)
    print('Top-3 movies with the highest ratings: ',', '.join(list(top3.keys())[:3]) )#pick top3
    print('**********************************')
    
def topone(csvdata,field):
    scores={} #accumulate score
    times={} 
    average={}
    for data in csvdata:
        for actor in data[field['actors']].split('|'): #use split to separate
            actor=actor.strip() #use lstrip to eliminate space
            if data[field['revenue (millions)']] !='': #avoid null
                if actor not in scores.keys(): #if does not exist previously
                    scores[actor]=float(data[field['revenue (millions)']])
                    times[actor]=1
                else: #if does
                    scores[actor]+=float(data[field['revenue (millions)']])
                    times[actor]+=1
    for name, score in scores.items():
        average[name]=score/times[name]
    top1={}
    top1={name:revenue for name,revenue in sorted(average.items(), key=lambda item:item[1], reverse=True)} #sort the dict
    
    answer=[]
    for key, value in top1.items():
        if value==max(top1.values()):
            answer.append(key)
        else:
            break
    
    print('The actor generating the highest average revenue: ',", ".join(answer))
    
    #print('The actor generating the highest average revenue: ',list(top1.keys())[0])
    print('**********************************')
def emma_average(csvdata,field):
    count=0
    rating=0
    for data in csvdata:
        if 'Emma Watson' in data[field['actors']]:
            rating+=float(data[field['rating']])
            count+=1
    print('The average rating of Emma Watson’s movies: ',rating/count)  
    print('**********************************')
def most_actors(csvdata,field):
    cooperate={} #a dic with using set as value
    for data in csvdata:
        temp={}
        temp=set(map(lambda x:x.strip(), data[field['actors']].split('|'))) #seperate the actors
        #print(temp)
        if data[field['director']] not in cooperate.keys():
            cooperate[data[field['director']]]=temp
        else:
            cooperate[data[field['director']]]=cooperate[data[field['director']]].union(temp) #to avoid duplicate actors
    top3_dir={}
    top3_dir={director:actors for director, actors in sorted(cooperate.items(), key=lambda item:len(item[1]), reverse=True)} #sort the dict
    

    answer=[]
    top3=[]
    for key, value in top3_dir.items():
        top3.append(len(value))
        if len(top3)==3:
            break
    
    for key, value in top3_dir.items():
        if len(value) in top3:
            answer.append(key)
        else:
            break
    
    print('Top-3 directors who collaborate with the most actors: ',', '.join(answer))
    print('**********************************')
def most_genres(csvdata,field):
    genres={}
    sorted_genres={}
    for data in csvdata:
        temp={}
        temp=list(map(lambda x:x.strip(), data[field['actors']].split('|'))) #seperate the actors
        for actor in  temp:
            if actor not in genres.keys():
                genres[actor]=set(data[field['genre']].split('|')) #use set to prevent duplicate data
            else:
                genres[actor]=genres[actor].union(set(data[field['genre']].split('|'))) 
    sorted_genres={name:genre for name,genre in sorted(genres.items(), key=lambda item:len(item[1]), reverse=True)}
    
    answer=[]
    top2=[]
    for key, value in sorted_genres.items():
        top2.append(len(value))
        if len(top2)==2:
            break
    
    for key, value in sorted_genres.items():
        if len(value) in top2:
            answer.append(key)
        else:
            break
    
    
    
    print('Top-2 actors playing in the most genres of movies: ',", ".join(answer))
    print('**********************************')
def largest_gap(csvdata,field):
    years={}
    for data in csvdata:
        temp={}
        temp=list(map(lambda x:x.strip(), data[field['actors']].split('|'))) #seperate the actors
        for actor in temp:
            if actor not in years.keys():
                years[actor]=set([int(data[field['year']])])
            else:
                years[actor]=years[actor].union(set([int(data[field['year']])]))

    gap={}
    for actor, year in years.items():
        gap[actor]=max(year)-min(year) #count the largest gap year
    gap={actor:years for actor, years in sorted(gap.items(), key=lambda item:item[1], reverse=True)} #sort the dict


    answer=[]
    for key, value in gap.items():
        if value==max(gap.values()):
            answer.append(key)
    print('Top-3 actors whose movies lead to the largest maximum gap of years: ',", ".join(answer))
    print('**********************************')
def collaborate(csvdata,johnny=set()):
    johnny.add('Johnny Depp')
    needmore=False
    for data in csvdata:
        temp=[i.strip() for i in data[field['actors']].split('|')] #seperate the actors
        for actor in temp:
            old_length=len(johnny)
            if actor in johnny:
                johnny=johnny.union(set(temp)) #add the direct and indirect actors into the set
            if old_length != len(johnny):
                needmore=True
    if needmore:
        collaborate(csvdata,johnny)
    else:
        johnny.remove('Johnny Depp')
        print('All actors who collaborate with Johnny Depp in direct and indirect ways: ',", ".join(list(johnny)))
        
    
mycsv=open("IMDB-Movie-Data.csv","r") #open file
csvdata=[]
for line in mycsv:
    line=line[:-1] #delete '/n' at the end
    csvdata.append(line.split(',')) #split line by field
field={csvdata[0][i].lower():i for i in range(len(csvdata[0]))} #field name dic
csvdata=csvdata[1:] #delete field name
#print(csvdata)
topthree(csvdata,field)
topone(csvdata,field)
emma_average(csvdata,field)
most_actors(csvdata,field)
most_genres(csvdata,field)
largest_gap(csvdata,field)
collaborate(csvdata)
# Out:
# Top-3 movies with the highest ratings:  Dangal, Kimi no na wa, Koe no katachi
# **********************************
# The actor generating the highest average revenue:  Daisy Ridley, John Boyega
# **********************************
# The average rating of Emma Watson’s movies:  7.175
# **********************************
# Top-3 directors who collaborate with the most actors:  Ridley Scott, M. Night Shyamalan, Danny Boyle, Paul W.S. Anderson
# **********************************
# Top-2 actors playing in the most genres of movies:  Brad Pitt, Hugh Jackman, Scarlett Johansson, Amy Adams, Chloe Grace Moretz, Johnny Depp
# **********************************
# Top-3 actors whose movies lead to the largest maximum gap of years:  Christian Bale, Anne Hathaway, Hugh Jackman, Scarlett Johansson, Matt Damon, Mark Wahlberg, Brad Pitt, Christopher Plummer, Tom Hanks, Bryce Dallas Howard, Chiwetel Ejiofor, Ben Kingsley, Gerard Butler, Eva Green, Judi Dench, Will Smith, Jennifer Connelly, Tom Cruise, Emily Blunt, Kevin Spacey, Samuel L. Jackson, Steve Carell, Edward Norton, Will Ferrell, Denzel Washington, Russell Crowe, Toni Collette, Meryl Streep, Morgan Freeman, Dominic West, Owen Wilson, Michelle Monaghan, Jessica Biel, Dustin Hoffman, Ben Whishaw, Paula Patton, Abbie Cornish, Johnny Depp, Jack Davenport, Rachel Weisz, Ellen Burstyn, Kang-ho Song, Jeremy Irons, Marion Cotillard, Kirsten Dunst, Jennifer Aniston, Justin Theroux, Maya Rudolph, Kate Bosworth, Audrey Tautou, Luke Wilson, Sacha Baron Cohen, Bob Balaban
# **********************************
# All actors who collaborate with Johnny Depp in direct and indirect ways:  Dakota Johnson, Kurt Russell, Rosemarie DeWitt, Karen Gillan, Aiden Longworth, Paddy Considine, Audrey Tautou, Emmanuelle Chriqui, Sam Elliott, David Morse, Vincent Kartheiser, Melissa Benoist, Rabah Nait Oufella, Mauricio Lopez, Gabriel Bateman, Ariel Levy, Alia Shawkat, Jo Hartley, ?lafur Darri ?lafsson, Barry Pepper, Tyler James Williams, Michael Fassbender, Jack Nicholson, Ed Helms, Pablo Schreiber, Will Poulter, Dana Fuchs, Keanu Reeves, Josh Wiggins, Amber Tamblyn, Tammy Blanchard, John Turturro, Anthony LaPaglia, Brandon T. Jackson, Rihanna, Willem Dafoe, Megan Charpentier, Ian McShane, Will Ferrell, Genesis Rodriguez, Anthony Hopkins, Linda Gegusch, Nicola Peltz, Ellen Burstyn, Teyonah Parris, Christian Bale, Tobias Menzies, Pierre Niney, Jonathan Groff, Dev Patel, Ewa Froling, Kevin Hart, Shannon Woodward, Brendan Fraser, Francesc Albiol, Richard Gere, Jonathan Roumie, Aaron Burns, Dustin Hoffman, Cedric the Entertainer, Lucy Fry, Danila Kozlovsky, Dan Fogler, Auli'i Cravalho, Nick Offerman, Patricia Clarkson, Ruben Blades, Will Smith, Karen Moskow, Kevin Bacon, Lesley Manville, Tom Hiddleston, Jessica Chastain, Travis Fimmel, Edward Asner, James Floyd, Alex R. Hibbert, Jason Segel, Chatchawai Kamonsakpitak, Richenda Carey, Mickey Rourke, Kevin Costner, David Wenham, Jennifer Connelly, Jane Fonda, Marcia Gay Harden, Danny McBride, Anton Yelchin, Sofia Black-D'Elia, Jean-Claude Van Damme, Walton Goggins, Jenny Slate, Alain Moussi, Jamal Woolard, Colin Farrell, Michael McDonald, Sanjeev Bhaskar, Mandy Moore, Christopher Mintz-Plasse, Jalil Lespert, Morgan Freeman, Ethan Suplee, Laurence Fishburne, Mila Kunis, Halle Berry, Claire Danes, Steve Lantz, Dan Stevens, Brittany Murphy, Jaime Winstone, Annabeth Gish, Eve, Bailey Anne Borders, David Thewlis, Josh Stewart, Seth Rogen, Frances O'Connor, Adria Arjona, Eddie Marsan, Jai Courtney, Giancarlo Esposito, Margarita Levieva, Natascha McElhone, Addison Timlin, Ella Rumpf, Doona Bae, Adam Brody, Ving Rhames, Jonny Weston, Thomas Middleditch, Alice Braga, Gemma Ward, Bradley Cooper, Sue Dahlman, Alexandra Maria Lara, Pierce Brosnan, Ellen Page, Lin Shaye, Josh Peck, Mathieu Amalric, Mo'Nique, Joseph Fiennes, Jovan Adepo, Fred Dalton Thompson, Matthew Morrison, Denzel Washington, Luke Evans, Laura Linney, Olivia Wilde, Rinko Kikuchi, Callan McAuliffe, Naomie Harris, Ray Romano, Michael Constantine, Taylor Kitsch, Elijah Smith, Jim Sturgess, Bridgette Barrett, Colin Hanks, Stacy Martin, Samuel L. Jackson, Angelina Jolie, Richard Madden, Aidan Quinn, Ed Oxenbould, Sarah Gadon, Kevin Kline, Morena Baccarin, Sandra Kinder, Riccardo Scamarcio, Nellie, Sigourney Weaver, Josh Duhamel, Ben Affleck, Fran Kranz, Mira Sorvino, F. Murray Abraham, Jeffrey Wright, Alistair Abell, Jessica Alba, Bonnie Hunt, Moon Bloodgood, Paula Prentiss, Angelo Josue Lozano Corzo, Mahershala Ali, Danielle Nicolet, James Ransone, Idris Elba, Michelle Rodriguez, Rizwan Manji, Steve Coogan, Nina Dobrev, Selena Gomez, Larry the Cable Guy, Hugh Grant, Adam Devine, Israel Broussard, Zac Efron, Jemima West, Martin Kabanza, Sarah Snook, Zoe Saldana, Shailene Woodley, Olga Kurylenko, Mia Wasikowska, Wei Tang, Freddy Rodriguez, Thandie Newton, Garrett M. Brown, Ryan Guzman, Ryan Reynolds, Luke Wilson, Lynsey Taylor Mackay, Christopher Lee, Tilda Swinton, Rodrigo Santoro, Josh Gad, Mary-Louise Parker, Beverly D'Angelo, Gemma Jones, J.K. Simmons, Ike Barinholtz, Melissa Leo, Lorraine Toussaint, Lily Collins, Janelle Monae, Jennifer Morrison, Nathalie Baye, Sullivan Stapleton, Jamie Foxx, John Doman, Andreas Wisniewski, Kate Beckinsale, John Cusack, Brian Cox, Isaiah Stone, Rachael Blake, Jeff Bridges, Diego Luna, Patrick Dempsey, Lauren Holly, David Lyons, Ciaran Hinds, Lily-Rose Depp, Demi Moore, Jake Johnson, Tony Goldwyn, Glenn Close, Karl Urban, Mason Lee, Freida Pinto, Tobey Maguire, Diego Klattenhoff, Clint Dyer, Robert Pattinson, Jack Reyno ...
# 1574

# %% [markdown]
# # 以下算出的top1有兩個

# %%
scores={} #accumulate score
times={} 
average={}
for data in csvdata:
    for actor in data[field['actors']].split('|'): #use split to separate
        actor=actor.strip() #use lstrip to eliminate space
        if data[field['revenue (millions)']] !='': #avoid null
            if actor not in scores.keys(): #if it does not exist previously
                scores[actor]=float(data[field['revenue (millions)']])
                times[actor]=1
            else: #if does
                scores[actor]+=float(data[field['revenue (millions)']])
                times[actor]+=1
for name, score in scores.items():
    average[name]=score/times[name]
top1={}
top1={name:revenue for name,revenue in sorted(average.items(), key=lambda item:item[1], reverse=True)} #sort the dict

answer=[]
for key, value in top1.items():
    if value==max(top1.values()):
        answer.append(key)
print(", ".join(answer))
# Out:
# Daisy Ridley, John Boyega
# ['Daisy Ridley', 'John Boyega']

# %%
count=0
rating=0
for data in csvdata:
    if 'Emma Watson' in data[field['actors']]:
        rating+=float(data[field['rating']]) #accumulate rating
        count+=1
print(rating/count) #calculate the average
# Out:
# 7.175

# %%
cooperate={} #a dic with using set as value
for data in csvdata:
    temp={}
    temp=set(map(lambda x:x.strip(), data[field['actors']].split('|'))) #seperate the actors
    #print(temp)
    if data[field['director']] not in cooperate.keys():
        cooperate[data[field['director']]]=temp
    else:
        cooperate[data[field['director']]]=cooperate[data[field['director']]].union(temp) #to avoid duplicate actors
top3_dir={}
top3_dir={director:actors for director, actors in sorted(cooperate.items(), key=lambda item:len(item[1]), reverse=True)} #sort the dict
print(top3_dir)
print(', '.join(list(top3_dir.keys())[:3]))
# Out:
# {'Ridley Scott': {'Noomi Rapace', 'Javier Bardem', 'Jessica Chastain', 'Penelope Cruz', 'Denzel Washington', 'Matthew Macfadyen', 'Kristen Wiig', 'Ben Kingsley', 'Sigourney Weaver', 'Marion Cotillard', 'Albert Finney', 'Charlize Theron', 'Logan Marshall-Green', 'Christian Bale', 'Josh Brolin', 'Chiwetel Ejiofor', 'Michael Fassbender', 'Abbie Cornish', 'Russell Crowe', 'Mark Strong', 'Joel Edgerton', 'Leonardo DiCaprio', 'Kate Mara', 'Golshifteh Farahani', 'Matt Damon', 'Max von Sydow', 'Cate Blanchett', 'Cameron Diaz'}, 'M. Night Shyamalan': {'Anya Taylor-Joy', 'Bryce Dallas Howard', 'Olivia DeJonge', 'Jessica Sula', 'Bob Balaban', 'Peter McRobbie', 'Dev Patel', 'Zooey Deschanel', 'Paul Giamatti', 'Noah Ringer', 'Haley Lu Richardson', 'Mark Wahlberg', 'David Denman', 'Jeffrey Wright', 'Deanna Dunagan', 'Ashlyn Sanchez', 'James McAvoy', 'John Leguizamo', 'Nicola Peltz', 'Jaden Smith', 'Sophie Okonedo', 'Ed Oxenbould', 'Will Smith', 'Jackson Rathbone'}, 'Danny Boyle': {'Danny Sapani', 'Amber Tamblyn', 'Dev Patel', 'Michelle Yeoh', 'Seth Rogen', 'James Franco', 'Anil Kapoor', 'Cillian Murphy', 'Sean Bott', 'Chris Evans', 'Jeff Daniels', 'Rose Byrne', 'Freida Pinto', 'Michael Fassbender', 'Vincent Cassel', 'James McAvoy', 'Kate Mara', 'Kate Winslet', 'Saurabh Shukla', 'Rosario Dawson'}, 'Paul W.S. Anderson': {'Shawn Roberts', 'Sienna Guillory', 'Milla Jovovich', 'Wentworth Miller', 'Kim Coates', 'Michelle Rodriguez', 'Ali Larter', 'Matthew Macfadyen', 'Kiefer Sutherland', 'Aryana Engineer', 'Tyrese Gibson', 'Kit Harington', 'Ian McShane', 'Ray Stevenson', 'Jason Statham', 'Iain Glen', 'Joan Allen', 'Emily Browning', 'Adewale Akinnuoye-Agbaje', 'Logan Lerman'}, 'Denis Villeneuve': {'Viola Davis', 'Mustafa Kamel', 'Lubna Azabal', 'Jake Gyllenhaal', 'Melanie Laurent', 'Emily Blunt', 'Melissa Leo', 'Maxim Gaudette', 'Forest Whitaker', 'Isabella Rossellini', 'Josh Brolin', 'Jeremy Renner', 'Amy Adams', 'Benicio Del Toro', 'Melissa Desormeaux-Poulin', 'Sarah Gadon', 'Hugh Jackman', 'Jon Bernthal', 'Michael Stuhlbarg'}, 'David Fincher': {'Brad Pitt', 'Anthony Edwards', 'Mark Ruffalo', 'Jesse Eisenberg', 'Tyler Perry', 'Tilda Swinton', 'Justin Timberlake', 'Stellan Skarsgard', 'Jake Gyllenhaal', 'Andrew Garfield', 'Rooney Mara', 'Christopher Plummer', 'Ben Affleck', 'Julia Ormond', 'Rosamund Pike', 'Daniel Craig', 'Cate Blanchett', 'Neil Patrick Harris', 'Robert Downey Jr.'}, 'Woody Allen': {'Javier Bardem', 'Sally Hawkins', 'Jesse Eisenberg', 'Owen Wilson', 'Peter Sarsgaard', 'Penelope Cruz', 'Rachel McAdams', 'Kristen Stewart', 'Christopher Evan Welch', 'Rebecca Hall', 'Kathy Bates', 'Blake Lively', 'Scarlett Johansson', 'Ellen Page', 'Kurt Fuller', 'Steve Carell', 'Alec Baldwin', 'Cate Blanchett', 'Woody Allen'}, 'Antoine Fuqua': {'Rhona Mitra', 'Chloe Grace Moretz', "Vincent D'Onofrio", 'Aaron Eckhart', 'Denzel Washington', 'Chris Pratt', 'Jake Gyllenhaal', 'Ethan Hawke', 'Angela Bassett', 'Rachel McAdams', 'Oona Laurence', 'Mark Wahlberg', 'Morgan Freeman', 'Danny Glover', 'Forest Whitaker', 'David Harbour', 'Michael Pena', 'Gerard Butler', 'Marton Csokas'}, 'J.J. Abrams': {'Tom Cruise', 'John Boyega', 'Simon Pegg', 'Elle Fanning', 'Ving Rhames', 'Philip Seymour Hoffman', 'Leonard Nimoy', 'Zoe Saldana', 'Chris Pine', 'Kyle Chandler', 'Oscar Isaac', 'Zachary Quinto', 'Joel Courtney', 'Benedict Cumberbatch', 'AJ Michalka', 'Michelle Monaghan', 'Daisy Ridley', 'Domhnall Gleeson'}, 'Zack Snyder': {'David Wenham', 'Henry Cavill', 'Dominic West', 'Carla Gugino', 'Ben Affleck', 'Patrick Wilson', 'Jesse Eisenberg', 'Diane Lane', 'Malin Akerman', 'Abbie Cornish', 'Amy Adams', 'Michael Shannon', 'Jena Malone', 'Emily Browning', 'Vanessa Hudgens', 'Gerard Butler', 'Jackie Earle Haley', 'Lena Headey'}, 'Peter Berg': {'J.K. Simmons', 'Liam Neeson', 'Charlize Theron', 'Alexander Skarsgard', 'James DuMont', 'Jason Bateman', 'John Goodman', 'Kurt Russell', 'Emile Hirsch', 'Brooklyn Decker', 'Rihanna', 'Michelle Monaghan', 'Jae Head', 'Ben Foster', ' ...
# Ridley Scott, M. Night Shyamalan, Danny Boyle

# %%
genres={}
sorted_genres={}
for data in csvdata:
    temp={}
    temp=list(map(lambda x:x.strip(), data[field['actors']].split('|'))) #seperate the actors
    for actor in  temp:
        if actor not in genres.keys():
            genres[actor]=set(data[field['genre']].split('|')) #use set to prevent duplicate data
        else:
            genres[actor]=genres[actor].union(set(data[field['genre']].split('|'))) 
sorted_genres={name:genre for name,genre in sorted(genres.items(), key=lambda item:len(item[1]), reverse=True)}
#print(", ".join(list(genres.keys())[:2]))
print(sorted_genres)





print(", ".join(list(sorted_genres.keys())[:2]))
# Out:
# {'Brad Pitt': {'War', 'Fantasy', 'Animation', 'Horror', 'Romance', 'Adventure', 'Crime', 'Biography', 'Comedy', 'Drama', 'Sport', 'Thriller', 'History', 'Action'}, 'Hugh Jackman': {'Fantasy', 'Animation', 'Romance', 'Adventure', 'Musical', 'Crime', 'Comedy', 'Biography', 'Drama', 'Mystery', 'Action', 'Sci-Fi', 'Family'}, 'Scarlett Johansson': {'Animation', 'Horror', 'Romance', 'Adventure', 'Comedy', 'Biography', 'Drama', 'Thriller', 'Mystery', 'History', 'Action', 'Sci-Fi', 'Family'}, 'Amy Adams': {'Fantasy', 'Animation', 'Romance', 'Adventure', 'Crime', 'Biography', 'Comedy', 'Drama', 'Thriller', 'Mystery', 'Action', 'Sci-Fi', 'Family'}, 'Chloe Grace Moretz': {'Fantasy', 'Horror', 'Music', 'Romance', 'Adventure', 'Crime', 'Comedy', 'Drama', 'Thriller', 'Mystery', 'Action', 'Sci-Fi', 'Family'}, 'Johnny Depp': {'Fantasy', 'Horror', 'Western', 'Romance', 'Adventure', 'Crime', 'Biography', 'Comedy', 'Drama', 'Mystery', 'Action', 'Musical', 'Family'}, 'Mark Wahlberg': {'Fantasy', 'Romance', 'Adventure', 'Crime', 'Biography', 'Comedy', 'Thriller', 'Drama', 'History', 'Action', 'Sci-Fi', 'Family'}, 'Charlize Theron': {'Animation', 'Western', 'Romance', 'Adventure', 'Crime', 'Comedy', 'Drama', 'Thriller', 'Mystery', 'Action', 'Sci-Fi', 'Family'}, 'Jake Gyllenhaal': {'Action', 'Fantasy', 'Romance', 'Adventure', 'Crime', 'Comedy', 'Thriller', 'Drama', 'Mystery', 'History', 'Sport', 'Sci-Fi'}, 'Liam Neeson': {'Western', 'Fantasy', 'Romance', 'Adventure', 'Crime', 'Comedy', 'Thriller', 'Drama', 'Mystery', 'History', 'Action', 'Sci-Fi'}, 'Jesse Eisenberg': {'Animation', 'Horror', 'Romance', 'Adventure', 'Crime', 'Biography', 'Comedy', 'Drama', 'Thriller', 'Mystery', 'Action', 'Sci-Fi'}, 'Rachel Weisz': {'Fantasy', 'Music', 'Romance', 'Adventure', 'Comedy', 'Biography', 'Drama', 'Thriller', 'Mystery', 'Action', 'Sci-Fi', 'Family'}, 'Christian Bale': {'Romance', 'Adventure', 'Crime', 'Comedy', 'Biography', 'Drama', 'Thriller', 'Mystery', 'History', 'Action', 'Sci-Fi'}, 'Leonardo DiCaprio': {'Western', 'Romance', 'Adventure', 'Crime', 'Comedy', 'Biography', 'Thriller', 'Drama', 'Mystery', 'Action', 'Sci-Fi'}, 'Anne Hathaway': {'Animation', 'Fantasy', 'Romance', 'Adventure', 'Comedy', 'Drama', 'Thriller', 'Sci-Fi', 'Action', 'Musical', 'Family'}, 'Tom Hardy': {'Romance', 'Adventure', 'Crime', 'Biography', 'Comedy', 'Drama', 'Sport', 'Thriller', 'Action', 'Sci-Fi', 'Mystery'}, 'Tom Hanks': {'Animation', 'Adventure', 'Crime', 'Comedy', 'Biography', 'Thriller', 'Drama', 'Mystery', 'History', 'Action', 'Sci-Fi'}, 'Teresa Palmer': {'Horror', 'Romance', 'Adventure', 'Crime', 'Biography', 'Comedy', 'Drama', 'Sport', 'History', 'Action', 'Sci-Fi'}, 'Joel Edgerton': {'Romance', 'Adventure', 'Crime', 'Biography', 'Sport', 'Drama', 'Thriller', 'History', 'Action', 'Sci-Fi', 'Mystery'}, 'Bradley Cooper': {'Horror', 'Romance', 'Adventure', 'Crime', 'Comedy', 'Biography', 'Drama', 'Thriller', 'Mystery', 'Action', 'Sci-Fi'}, 'Domhnall Gleeson': {'Fantasy', 'Romance', 'Adventure', 'Comedy', 'Biography', 'Thriller', 'Drama', 'Mystery', 'Sport', 'Action', 'Sci-Fi'}, 'Chiwetel Ejiofor': {'Fantasy', 'Romance', 'Adventure', 'Crime', 'Biography', 'Drama', 'Thriller', 'Mystery', 'History', 'Action', 'Sci-Fi'}, 'Michael Fassbender': {'War', 'Romance', 'Adventure', 'Crime', 'Biography', 'Drama', 'Thriller', 'Mystery', 'History', 'Action', 'Sci-Fi'}, 'Liev Schreiber': {'Romance', 'Adventure', 'Crime', 'Biography', 'Comedy', 'Drama', 'Sport', 'Mystery', 'History', 'Action', 'Sci-Fi'}, 'James McAvoy': {'Fantasy', 'Horror', 'Romance', 'Adventure', 'Crime', 'Comedy', 'Drama', 'Thriller', 'Mystery', 'Action', 'Sci-Fi'}, 'Will Smith': {'Fantasy', 'Horror', 'Romance', 'Adventure', 'Crime', 'Biography', 'Comedy', 'Drama', 'Sport', 'Action', 'Sci-Fi'}, 'Ethan Hawke': {'Western', 'Horror', 'Romance', 'Adventure', 'Crime', 'Biography', 'Drama', 'Thriller', 'Mystery', 'Action', 'Sci-Fi'}, 'Sandra Bullock': {'Animation', 'Romance', 'Adventure', 'Crime', 'Biography', 'Comedy', 'Thr ...
# Brad Pitt, Hugh Jackman

# %% [markdown]
# # 以下有多個答案

# %%
years={}
for data in csvdata:
    temp={}
    temp=list(map(lambda x:x.strip(), data[field['actors']].split('|'))) #seperate the actors
    for actor in temp:
        if actor not in years.keys():
            years[actor]=set([int(data[field['year']])])
        else:
            years[actor]=years[actor].union(set([int(data[field['year']])]))
            
gap={}
for actor, year in years.items():
    gap[actor]=max(year)-min(year) #count the largest gap year
gap={actor:years for actor, years in sorted(gap.items(), key=lambda item:item[1], reverse=True)} #sort the dict
#print(gap)

answer=[]
for key, value in gap.items():
    if value==max(gap.values()):
        answer.append(key)
print(", ".join(answer))
# Out:
# Christian Bale, Anne Hathaway, Hugh Jackman, Scarlett Johansson, Matt Damon, Mark Wahlberg, Brad Pitt, Christopher Plummer, Tom Hanks, Bryce Dallas Howard, Chiwetel Ejiofor, Ben Kingsley, Gerard Butler, Eva Green, Judi Dench, Will Smith, Jennifer Connelly, Tom Cruise, Emily Blunt, Kevin Spacey, Samuel L. Jackson, Steve Carell, Edward Norton, Will Ferrell, Denzel Washington, Russell Crowe, Toni Collette, Meryl Streep, Morgan Freeman, Dominic West, Owen Wilson, Michelle Monaghan, Jessica Biel, Dustin Hoffman, Ben Whishaw, Paula Patton, Abbie Cornish, Johnny Depp, Jack Davenport, Rachel Weisz, Ellen Burstyn, Kang-ho Song, Jeremy Irons, Marion Cotillard, Kirsten Dunst, Jennifer Aniston, Justin Theroux, Maya Rudolph, Kate Bosworth, Audrey Tautou, Luke Wilson, Sacha Baron Cohen, Bob Balaban

# %%
def collaborate(csvdata,johnny=set()):
    johnny.add('Johnny Depp')
    needmore=False
    for data in csvdata:
        temp=[i.strip() for i in data[field['actors']].split('|')] #seperate the actors
        #print(temp)
        for actor in temp:
            old_length=len(johnny)
            if actor in johnny:
                johnny=johnny.union(set(temp)) #add the direct and indirect actors into the set
            if old_length != len(johnny):
                needmore=True
    if needmore:
        collaborate(csvdata,johnny)
    else:
        print(johnny)
collaborate(csvdata)
# Out:
# {"Fionn O'Shea", 'Daniel Henshall', 'Lia Marie Johnson', 'Ruth Negga', 'Eddie Murphy', 'Dougie McConnell', 'Paul Bettany', 'Eddie Izzard', 'Max Irons', 'Javier Bardem', 'Marton Csokas', 'Elizabeth Banks', 'Mary Steenburgen', 'Selma Blair', 'Michael Ealy', 'Ella Rumpf', 'Rebecca Ferguson', 'Ruby Barnhill', "Jerry O'Connell", 'Chloe Grace Moretz', 'Sally Hawkins', 'Romain Duris', 'Graham McTavish', 'Daniella Kertesz', 'Jason Schwartzman', 'Christian Stevens', 'Steve Tom', 'Julianne Moore', 'Blake Jenner', 'Eric Godon', 'Terrence Howard', 'Brenda Blethyn', 'Bruce Willis', 'Oaklee Pendergast', 'Hayley Atwell', 'Jake Gyllenhaal', 'Rosemarie DeWitt', 'Teri Hatcher', 'Matthias Schoenaerts', 'Andy Samberg', 'Juan Saavedra', 'Kevin Kline', 'Mandy Gonzalez', 'Trey Songz', 'Kyra Sedgwick', 'Kieran Culkin', 'Sacha Baron Cohen', 'Richard Armitage', 'Charlie Cox', 'Joe Manganiello', 'Terry Crews', 'Hugh Grant', 'Annette Bening', 'Oliver Cooper', 'Kara Hayward', 'Lauren Graham', 'Brian Dennehy', 'Kodi Smit-McPhee', 'Noah Wiseman', 'Amber Tamblyn', 'Jennifer Ehle', 'Quinton Aaron', 'Brady Corbet', 'Katherine Heigl', 'Jay Baruchel', 'Noah Taylor', 'Thandie Newton', 'Val Kilmer', 'Keira Knightley', 'Zachary Levi', 'Pierce Brosnan', 'Victoria Justice', 'Diego Klattenhoff', 'Dennis Quaid', 'Mackenzie Foy', 'Jonathan Daniel Brown', 'Carmen Ejogo', 'James Hamrick', 'Wentworth Miller', 'Analeigh Tipton', 'Marcia Gay Harden', 'Nikki Blonsky', 'Maria Bello', 'Stacy Martin', 'James Marsden', 'Thomas Brodie-Sangster', 'Dan Stevens', 'Jamie Chung', 'Abigail Breslin', 'Isabelle Fuhrman', 'Isabella Rossellini', 'Renee Zellweger', 'Marley Shelton', 'Essie Davis', 'Christina Applegate', 'Ni Ni', 'Matthew Zuk', 'Rima Te Wiata', 'Kurt Russell', 'Billy Crudup', 'Rachel Wood', 'Sean Faris', 'Garrett Hedlund', 'Sandra Kinder', 'Steve Zahn', 'Elisabeth Moss', 'Yu-mi Jung', 'Cary Joji Fukunaga', 'Eric Bana', 'Max Minghella', 'Owen Wilson', 'Zooey Deschanel', 'Luke Wilson', 'Daniel Bruhl', 'Helena Bonham Carter', 'America Ferrera', 'Hilary Swank', 'Rodrigo Santoro', 'Lily Rabe', 'Jake Johnson', "Vincent D'Onofrio", 'Scott Eastwood', 'Lynsey Taylor Mackay', 'Lois van Wijk', 'Tyrese Gibson', 'Liana Liberato', 'Mathieu Amalric', 'Colm Meaney', 'Ciaran Hinds', 'Oscar Isaac', 'Kiefer Sutherland', 'Keanu Reeves', 'Jorma Taccone', 'Duan Sanderson', 'Michael Kenneth Williams', 'Klara Kristin', 'Ray Stevenson', 'Riz Ahmed', 'Alan Alda', 'Idina Menzel', 'Thomas Middleditch', 'Sylvester Stallone', 'Vicky Krieps', 'Charlie Heaton', 'AJ Michalka', 'Rachael Blake', 'Iain Glen', 'Paul Walker', 'Eddie Marsan', 'Sean Penn', 'Gattlin Griffith', 'Aidan Quinn', '50 Cent', 'Christopher Fitzgerald', 'Judy Greer', 'Chris Messina', 'Diane Lane', 'James Franco', "Dylan O'Brien", 'Bokeem Woodbine', 'Til Schweiger', 'Christian Bale', 'Jeffrey Wright', 'Jeffrey Dean Morgan', 'Alex R. Hibbert', 'Zach Grenier', 'Robin Wright', 'Cillian Murphy', 'Mark Strong', 'Ben Walker', 'Jennifer Lawrence', 'Rasmus Hardiker', 'Jane Fonda', 'Tyler James Williams', 'Dan Byrd', 'Robin Williams', 'Donnie Yen', 'Sophie Perry', 'Russell Crowe', 'Michael Dickson', 'Bill Hader', 'Carmen Electra', 'Freddy Rodriguez', 'Barry Pepper', 'Ronnie Gene Blevins', 'Maria Doyle Kennedy', 'Dianna Agron', 'Walton Goggins', 'Samantha Isler', 'Hunter McCracken', 'Antonio Banderas', 'Skyler Gisondo', 'Brian Geraghty', 'Sophie Nelisse', 'Rosie Huntington-Whiteley', 'Craig T. Nelson', 'Felicity Jones', 'Rob Riggle', 'Kevin Hart', 'Jeff Bridges', 'Ryan Potter', 'Olivia DeJonge', 'Woody Allen', 'Jacob Tremblay', 'Alexis Dziena', 'Keith Carradine', 'Brian Cox', 'Aaron Eckhart', 'Michael Stuhlbarg', 'Tyler Perry', 'Alex Pettyfer', 'Brandon T. Jackson', 'Tim McGraw', 'John Carroll Lynch', 'Ashley Benson', 'Rachel Korine', 'Cole Konis', 'Andrea Whitburn', 'Eddie Baroo', 'Tom Cruise', 'Leehom Wang', 'Jackson Rathbone', 'Gemma Arterton', 'Annabelle Attanasio', 'Ji-min Han', 'Anders Danielsen Lie', 'Jason Segel', 'Ashlyn Sanchez', 'Catherine K ...

# %%
# Out:
# True
